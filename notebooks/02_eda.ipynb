# %% [markdown]
# # Exploratory Data Analysis
#
# This notebook contains the exploratory data analysis for the CardioRisk AI project. The actual generation of the report and plots is handled by `scripts/run_eda.py` to ensure consistency and reusability.

# %%
import sys
from pathlib import Path
sys.path.append(str(Path.cwd().parent))

from scripts.run_eda import run_eda
run_eda()
